# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# !pwd
# !rm -rf /content/neural_seq_decoder
# !git clone https://github.com/vickysmt/neural_seq_decoder.git
# %cd /content/neural_seq_decoder
# !pwd
# !mkdir speech_logs
# Out:
# /content
# /content
# Cloning into 'neural_seq_decoder'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 114 (delta 52), reused 98 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 401.59 KiB | 26.77 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /content/neural_seq_decoder
# /content/neural_seq_decoder

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/neural_seq_decoder
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (1.13.1)
# Requirement already satisfied: hydra-core==1.3.2 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (1.3.2)
# Requirement already satisfied: hydra-submitit-launcher==1.1.5 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (1.1.5)
# Requirement already satisfied: hydra-optuna-sweeper==1.2.0 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (1.2.0)
# Requirement already satisfied: numpy==1.25.0 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (1.25.0)
# Requirement already satisfied: scipy==1.11.1 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (1.11.1)
# Requirement already satisfied: numba==0.58.1 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (0.58.1)
# Requirement already satisfied: scikit-learn==1.3.2 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (1.3.2)
# Requirement already satisfied: g2p_en==2.1.0 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (2.1.0)
# Requirement already satisfied: edit_distance==1.0.6 in /usr/local/lib/python3.11/dist-packages (from neural_decoder==0.0.1) (1.0.6)
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.11/dist-packages (from g2p_en==2.1.0->neural_decoder==0.0.1) (3.9.1)
# Requirement already satisfied: inflect>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from g2p_en==2.1.0->neural_decoder==0.0.1) (7.5.0)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from g2p_en==2.1.0->neural_decoder==0.0.1) (0.1.3)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2->neural_decoder==0.0.1) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2->neural_decoder==0.0.1) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from hydra-core==1.3.2->neural_decoder==0.0.1) (24.2)
# Requirement already satisfied: optuna<3.0.0,>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (2.10.1)
# Requirement already satisfied: submitit>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from hydra-submitit-launcher==1.1.5->neural_decoder==0.0.1) (1.5.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba==0.58.1->neural_decoder==0.0.1) (0.41.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2->neural_decoder==0.0.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2->neural_decoder==0.0.1) (3.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1->neural_decoder==0.0.1) (4.12.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1->neural_decoder==0.0.1) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1->neural_decoder==0.0.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1->neural_decoder==0.0.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch==1.13.1->neural_decoder==0.0.1) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->neural_decoder==0.0.1) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->neural_decoder==0.0.1) (0.45.1)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=0.3.1->g2p_en==2.1.0->neural_decoder==0.0.1) (10.6.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=0.3.1->g2p_en==2.1.0->neural_decoder==0.0.1) (4.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.4->g2p_en==2.1.0->neural_decoder==0.0.1) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.4->g2p_en==2.1.0->neural_decoder==0.0.1) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.4->g2p_en==2.1.0->neural_decoder==0.0.1) (4.67.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf<2.4,>=2.2->hydra-core==1.3.2->neural_decoder==0.0.1) (6.0.2)
# Requirement already satisfied: alembic in /usr/local/lib/python3.11/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (1.15.2)
# Requirement already satisfied: cliff in /usr/local/lib/python3.11/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (4.9.1)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.11/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (0.11.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (2.0.39)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from submitit>=1.0.0->hydra-submitit-launcher==1.1.5->neural_decoder==0.0.1) (3.1.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.1.0->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (3.1.1)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (1.1.3)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (0.5.2)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (2.5.11)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (3.15.1)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (5.4.1)
# Requirement already satisfied: pyperclip>=1.8 in /usr/local/lib/python3.11/dist-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (1.9.0)
# Requirement already satisfied: wcwidth>=0.2.10 in /usr/local/lib/python3.11/dist-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (0.2.13)
# Requirement already satisfied: pbr>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from stevedore>=2.0.1->cliff->optuna<3.0.0,>=2.10.0->hydra-optuna-sweeper==1.2.0->neural_decoder==0.0.1) (6.1.1)
# Building wheels for collected packages: neural_decoder
#   Building editable for neural_decoder (pyproject.toml) ... done
#   Created wheel for neural_decoder: filename=neural_decoder-0.0.1-0.editable-py3-none-any.whl size=1614 sha256=1b439d374d6153515e4be596d2929f520fba224e896d83c6bf0f4d4f1d62f157
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3ebt9me8/wheels/6a/6b/c0/e8177169341dad56613c1ff48aa7de852bc838b5bdbe76424d
# Successfully built neural_decoder
# Installing collected packages: neural_decoder
#   Attempting uninstall: neural_decoder
#     Found existing installation: neural_decoder 0.0.1
#     Uninstalling neural_decoder-0.0.1:
#       Successfully uninstalled neural_decoder-0.0.1
# Successfully installed neural_decoder-0.0.1

# %%
# !pip install -qU wandb
import wandb
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: mengtong-shi (mengtong-shi-mcgill-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
modelName = 'speechGRUw/oLayerNorm'

args = {}
args["model_type"] = "GRU"
args['outputDir'] = '/content/neural_seq_decoder/speech_logs/' + modelName
args['datasetPath'] = '/content/drive/MyDrive/Colab Notebooks/ECSE 552/Project/ptDecoder_ctc'
args['seqLen'] = 150
args['maxTimeSeriesLen'] = 1200
args['batchSize'] = 64
args['lrStart'] = 0.02
args['lrEnd'] = 0.02
args['nUnits'] = 512 #1024
args['nBatch'] = 10000
args['nLayers'] = 3 #5
args['seed'] = 0
args['nClasses'] = 40
args['nInputFeatures'] = 256
args['dropout'] = 0.4
args['whiteNoiseSD'] = 0.8
args['constantOffsetSD'] = 0.2
args['gaussianSmoothWidth'] = 2.0
args['strideLen'] = 4
args['kernelLen'] = 32
args['bidirectional'] = True
args['l2_decay'] = 1e-5

args['earlyStop_patience'] = 10
args['earlyStop_minChange'] = 0.005
args['nEpochs'] = 100
args['gradClipVal'] = 10

# %%
run = wandb.init(
    project="ECSE552-Project",
    name=modelName,
    config=args,
)
# Out:
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/neural_seq_decoder/wandb/run-20250328_183625-mbrty2vl</code>
# Syncing run <strong><a href='https://wandb.ai/mengtong-shi-mcgill-university/ECSE552-Project/runs/mbrty2vl' target="_blank">speechGRUw/oLayerNorm</a></strong> to <a href='https://wandb.ai/mengtong-shi-mcgill-university/ECSE552-Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mengtong-shi-mcgill-university/ECSE552-Project' target="_blank">https://wandb.ai/mengtong-shi-mcgill-university/ECSE552-Project</a>
#  View run at <a href='https://wandb.ai/mengtong-shi-mcgill-university/ECSE552-Project/runs/mbrty2vl' target="_blank">https://wandb.ai/mengtong-shi-mcgill-university/ECSE552-Project/runs/mbrty2vl</a>

# %%
from src.neural_decoder.rnn_trainer import trainModel

trainModel(args)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch 1/100:   0%|                                                          | 0/138 [00:00<?, ?it/s]/content/neural_seq_decoder/src/neural_decoder/rnn_trainer.py:152: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at ../aten/src/ATen/native/Convolution.cpp:895.)
#   pred = model.forward(X, dayIdx)
# Epoch 1/100: 100%|████████████████████████████████████████████████| 138/138 [00:16<00:00,  8.15it/s]
# epoch 0, train ctc loss: 3.108318, val ctc loss: 2.594736, val cer: 0.794658, grad norm: 0.887358 time/epoch:  17.759 seconds
# Epoch 2/100: 100%|████████████████████████████████████████████████| 138/138 [00:15<00:00,  9.05it/s]
# epoch 1, train ctc loss: 2.454863, val ctc loss: 2.167739, val cer: 0.664441, grad norm: 1.211396 time/epoch:  15.821 seconds
# Epoch 3/100: 100%|████████████████████████████████████████████████| 138/138 [00:15<00:00,  9.03it/s]
# epoch 2, train ctc loss: 2.181008, val ctc loss: 1.976493, val cer: 0.600167, grad norm: 1.332246 time/epoch:  15.855 seconds
# Epoch 4/100: 100%|████████████████████████████████████████████████| 138/138 [00:15<00:00,  9.10it/s]
# epoch 3, train ctc loss: 2.027477, val ctc loss: 1.848764, val cer: 0.564274, grad norm: 1.225752 time/epoch:  15.736 seconds
# Epoch 5/100: 100%|████████████████████████████████████████████████| 138/138 [00:15<00:00,  8.96it/s]
# epoch 4, train ctc loss: 1.905965, val ctc loss: 1.737479, val cer: 0.512521, grad norm: 1.324887 time/epoch:  16.011 seconds
# Epoch 6/100: 100%|████████████████████████████████████████████████| 138/138 [00:15<00:00,  9.12it/s]
# epoch 5, train ctc loss: 1.798524, val ctc loss: 1.636212, val cer: 0.486644, grad norm: 1.406194 time/epoch:  15.705 seconds
# Epoch 7/100: 100%|████████████████████████████████████████████████| 138/138 [00:15<00:00,  9.01it/s]
# epoch 6, train ctc loss: 1.704321, val ctc loss: 1.555316, val cer: 0.461603, grad norm: 1.491868 time/epoch:  15.883 seconds
# Epoch 8/100: 100%|████████████████████████████████████████████████| 138/138 [00:15<00:00,  9.20it/s]
# epoch 7, train ctc loss: 1.614553, val ctc loss: 1.480636, val cer: 0.440735, grad norm: 1.336622 time/epoch:  15.597 seconds
# Epoch 9/100: 100%|████████████████████████████████████████████████| 138/138 [00:15<00:00,  9.15it/s]
# epoch 8, train ctc loss: 1.539209, val ctc loss: 1.413161, val cer: 0.424040, grad norm: 1.482547 time/epoch:  15.655 seconds
# Epoch 10/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.08it/s]
# epoch 9, train ctc loss: 1.470598, val ctc loss: 1.365871, val cer: 0.404841, grad norm: 1.418630 time/epoch:  15.789 seconds
# Epoch 11/100: 100%|███████████████████████████████████████████████| 138/138 [00:14<00:00,  9.27it/s]
# epoch 10, train ctc loss: 1.405464, val ctc loss: 1.312045, val cer: 0.398998, grad norm: 1.352464 time/epoch:  15.470 seconds
# Epoch 12/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.13it/s]
# epoch 11, train ctc loss: 1.350364, val ctc loss: 1.272024, val cer: 0.394825, grad norm: 1.429265 time/epoch:  15.730 seconds
# Epoch 13/100: 100%|███████████████████████████████████████████████| 138/138 [00:14<00:00,  9.21it/s]
# epoch 12, train ctc loss: 1.301528, val ctc loss: 1.232076, val cer: 0.386477, grad norm: 1.414762 time/epoch:  15.557 seconds
# Epoch 14/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.16it/s]
# epoch 13, train ctc loss: 1.254262, val ctc loss: 1.199635, val cer: 0.369783, grad norm: 1.393107 time/epoch:  15.650 seconds
# Epoch 15/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.15it/s]
# epoch 14, train ctc loss: 1.209544, val ctc loss: 1.168003, val cer: 0.354758, grad norm: 1.338305 time/epoch:  15.668 seconds
# Epoch 16/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.10it/s]
# epoch 15, train ctc loss: 1.173502, val ctc loss: 1.143359, val cer: 0.349750, grad norm: 1.705628 time/epoch:  15.743 seconds
# Epoch 17/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.04it/s]
# epoch 16, train ctc loss: 1.135199, val ctc loss: 1.122995, val cer: 0.351419, grad norm: 1.532641 time/epoch:  15.856 seconds
# Epoch 18/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.96it/s]
# epoch 17, train ctc loss: 1.100169, val ctc loss: 1.099926, val cer: 0.332220, grad norm: 1.478375 time/epoch:  15.984 seconds
# Epoch 19/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.20it/s]
# epoch 18, train ctc loss: 1.068149, val ctc loss: 1.080922, val cer: 0.329716, grad norm: 1.494111 time/epoch:  15.579 seconds
# Epoch 20/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.12it/s]
# epoch 19, train ctc loss: 1.037799, val ctc loss: 1.069545, val cer: 0.320534, grad norm: 1.430950 time/epoch:  15.709 seconds
# Epoch 21/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.16it/s]
# epoch 20, train ctc loss: 1.012870, val ctc loss: 1.051395, val cer: 0.309683, grad norm: 1.531359 time/epoch:  15.638 seconds
# Epoch 22/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.14it/s]
# epoch 21, train ctc loss: 0.985365, val ctc loss: 1.034356, val cer: 0.316361, grad norm: 1.385621 time/epoch:  15.702 seconds
# Epoch 23/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.16it/s]
# epoch 22, train ctc loss: 0.962033, val ctc loss: 1.019127, val cer: 0.309683, grad norm: 1.351179 time/epoch:  15.673 seconds
# Epoch 24/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.18it/s]
# epoch 23, train ctc loss: 0.933947, val ctc loss: 1.010038, val cer: 0.308013, grad norm: 1.543886 time/epoch:  15.606 seconds
# Epoch 25/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.96it/s]
# epoch 24, train ctc loss: 0.910527, val ctc loss: 1.000052, val cer: 0.304674, grad norm: 1.429875 time/epoch:  16.004 seconds
# Epoch 26/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.07it/s]
# epoch 25, train ctc loss: 0.888904, val ctc loss: 0.984594, val cer: 0.299666, grad norm: 1.494767 time/epoch:  15.796 seconds
# Epoch 27/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.13it/s]
# epoch 26, train ctc loss: 0.868051, val ctc loss: 0.974953, val cer: 0.296327, grad norm: 1.503992 time/epoch:  15.696 seconds
# Epoch 28/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.13it/s]
# epoch 27, train ctc loss: 0.848141, val ctc loss: 0.963585, val cer: 0.303005, grad norm: 1.552893 time/epoch:  15.698 seconds
# Epoch 29/100: 100%|███████████████████████████████████████████████| 138/138 [00:14<00:00,  9.21it/s]
# epoch 28, train ctc loss: 0.826180, val ctc loss: 0.958365, val cer: 0.282972, grad norm: 1.505582 time/epoch:  15.582 seconds
# Epoch 30/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.17it/s]
# epoch 29, train ctc loss: 0.807473, val ctc loss: 0.949704, val cer: 0.283806, grad norm: 1.470754 time/epoch:  15.620 seconds
# Epoch 31/100: 100%|███████████████████████████████████████████████| 138/138 [00:14<00:00,  9.22it/s]
# epoch 30, train ctc loss: 0.792077, val ctc loss: 0.941885, val cer: 0.276294, grad norm: 1.478548 time/epoch:  15.562 seconds
# Epoch 32/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.04it/s]
# epoch 31, train ctc loss: 0.776204, val ctc loss: 0.933413, val cer: 0.287145, grad norm: 1.540641 time/epoch:  15.860 seconds
# Epoch 33/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.05it/s]
# epoch 32, train ctc loss: 0.756850, val ctc loss: 0.928595, val cer: 0.293823, grad norm: 1.569891 time/epoch:  15.834 seconds
# Epoch 34/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.04it/s]
# epoch 33, train ctc loss: 0.741619, val ctc loss: 0.920005, val cer: 0.284641, grad norm: 1.573725 time/epoch:  15.847 seconds
# Epoch 35/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.14it/s]
# epoch 34, train ctc loss: 0.721633, val ctc loss: 0.916648, val cer: 0.292154, grad norm: 1.457073 time/epoch:  15.671 seconds
# Epoch 36/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.10it/s]
# epoch 35, train ctc loss: 0.709205, val ctc loss: 0.911090, val cer: 0.279633, grad norm: 1.519587 time/epoch:  15.777 seconds
# Epoch 37/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.17it/s]
# epoch 36, train ctc loss: 0.693956, val ctc loss: 0.909015, val cer: 0.283806, grad norm: 1.558811 time/epoch:  15.619 seconds
# Epoch 38/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.18it/s]
# epoch 37, train ctc loss: 0.679823, val ctc loss: 0.899381, val cer: 0.277129, grad norm: 1.438891 time/epoch:  15.609 seconds
# Epoch 39/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.06it/s]
# epoch 38, train ctc loss: 0.667160, val ctc loss: 0.898582, val cer: 0.270451, grad norm: 1.564192 time/epoch:  15.819 seconds
# Epoch 40/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.06it/s]
# epoch 39, train ctc loss: 0.654822, val ctc loss: 0.896908, val cer: 0.275459, grad norm: 1.554863 time/epoch:  15.820 seconds
# Epoch 41/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.08it/s]
# epoch 40, train ctc loss: 0.640334, val ctc loss: 0.890229, val cer: 0.276294, grad norm: 1.703064 time/epoch:  15.779 seconds
# Epoch 42/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.93it/s]
# epoch 41, train ctc loss: 0.625632, val ctc loss: 0.886242, val cer: 0.272955, grad norm: 1.696153 time/epoch:  16.034 seconds
# Epoch 43/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.73it/s]
# epoch 42, train ctc loss: 0.613264, val ctc loss: 0.884031, val cer: 0.268781, grad norm: 1.556449 time/epoch:  16.396 seconds
# Epoch 44/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.13it/s]
# epoch 43, train ctc loss: 0.602127, val ctc loss: 0.878070, val cer: 0.260434, grad norm: 1.603774 time/epoch:  15.689 seconds
# Epoch 45/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.89it/s]
# epoch 44, train ctc loss: 0.590035, val ctc loss: 0.883083, val cer: 0.268781, grad norm: 1.670971 time/epoch:  16.118 seconds
# Epoch 46/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.94it/s]
# epoch 45, train ctc loss: 0.577249, val ctc loss: 0.885420, val cer: 0.263773, grad norm: 1.602957 time/epoch:  16.049 seconds
# Epoch 47/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.09it/s]
# epoch 46, train ctc loss: 0.567255, val ctc loss: 0.881387, val cer: 0.257095, grad norm: 1.737106 time/epoch:  15.757 seconds
# Epoch 48/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.04it/s]
# epoch 47, train ctc loss: 0.556032, val ctc loss: 0.878269, val cer: 0.270451, grad norm: 1.423364 time/epoch:  15.834 seconds
# Epoch 49/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.01it/s]
# epoch 48, train ctc loss: 0.544723, val ctc loss: 0.873872, val cer: 0.258765, grad norm: 1.595715 time/epoch:  15.900 seconds
# Epoch 50/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.12it/s]
# epoch 49, train ctc loss: 0.533058, val ctc loss: 0.878983, val cer: 0.257095, grad norm: 1.708767 time/epoch:  15.724 seconds
# Epoch 51/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.98it/s]
# epoch 50, train ctc loss: 0.523683, val ctc loss: 0.877032, val cer: 0.251252, grad norm: 1.577913 time/epoch:  15.976 seconds
# Epoch 52/100: 100%|███████████████████████████████████████████████| 138/138 [00:14<00:00,  9.25it/s]
# epoch 51, train ctc loss: 0.512134, val ctc loss: 0.874298, val cer: 0.241235, grad norm: 1.644277 time/epoch:  15.524 seconds
# Epoch 53/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.15it/s]
# epoch 52, train ctc loss: 0.505454, val ctc loss: 0.864350, val cer: 0.238731, grad norm: 1.748144 time/epoch:  15.662 seconds
# Epoch 54/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.10it/s]
# epoch 53, train ctc loss: 0.494192, val ctc loss: 0.868865, val cer: 0.249583, grad norm: 1.500847 time/epoch:  15.739 seconds
# Epoch 55/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.16it/s]
# epoch 54, train ctc loss: 0.487050, val ctc loss: 0.870267, val cer: 0.243740, grad norm: 1.570616 time/epoch:  15.633 seconds
# Epoch 56/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.94it/s]
# epoch 55, train ctc loss: 0.474913, val ctc loss: 0.872876, val cer: 0.249583, grad norm: 1.406256 time/epoch:  16.027 seconds
# Epoch 57/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.96it/s]
# epoch 56, train ctc loss: 0.468181, val ctc loss: 0.868400, val cer: 0.247913, grad norm: 1.777491 time/epoch:  16.006 seconds
# Epoch 58/100: 100%|███████████████████████████████████████████████| 138/138 [00:14<00:00,  9.21it/s]
# epoch 57, train ctc loss: 0.459755, val ctc loss: 0.866564, val cer: 0.249583, grad norm: 1.719928 time/epoch:  15.561 seconds
# Epoch 59/100: 100%|███████████████████████████████████████████████| 138/138 [00:14<00:00,  9.28it/s]
# epoch 58, train ctc loss: 0.449142, val ctc loss: 0.866877, val cer: 0.252087, grad norm: 1.692049 time/epoch:  15.452 seconds
# Epoch 60/100: 100%|███████████████████████████████████████████████| 138/138 [00:14<00:00,  9.21it/s]
# epoch 59, train ctc loss: 0.442040, val ctc loss: 0.868060, val cer: 0.232888, grad norm: 1.916097 time/epoch:  15.583 seconds
# Epoch 61/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  9.01it/s]
# epoch 60, train ctc loss: 0.431268, val ctc loss: 0.866639, val cer: 0.243740, grad norm: 1.618792 time/epoch:  15.900 seconds
# Epoch 62/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.98it/s]
# epoch 61, train ctc loss: 0.427088, val ctc loss: 0.870296, val cer: 0.239566, grad norm: 1.457254 time/epoch:  15.953 seconds
# Epoch 63/100: 100%|███████████████████████████████████████████████| 138/138 [00:15<00:00,  8.98it/s]
# epoch 62, train ctc loss: 0.417849, val ctc loss: 0.872979, val cer: 0.246244, grad norm: 1.458788 time/epoch:  15.956 seconds
# Early stopping
